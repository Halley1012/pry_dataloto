# %%
import pandas as pd
import numpy as np

csv = pd.read_csv(
    'D:/Michael/miloto/ArchivosExcel/resultados-loteria-de-bogota.csv', sep=';' , encoding='latin1'
)
print(csv.head(50))
# Out:
#     LOTERIA SORTEO      FECHA                    NOMBRE_PREMIO  NUMERO  SERIE
# 0         2   2216  2/01/2014  PREMIO MAYOR DE $2.800 MILLONES    4316     48
# 1         2   2216  2/01/2014         PREMIO SECO $10 MILLONES    5777     41
# 2         2   2216  2/01/2014         PREMIO SECO $10 MILLONES    1873    110
# 3         2   2216  2/01/2014         PREMIO SECO $10 MILLONES    6850     67
# 4         2   2216  2/01/2014         PREMIO SECO $10 MILLONES    1731     85
# 5         2   2216  2/01/2014         PREMIO SECO $10 MILLONES    9250      1
# 6         2   2216  2/01/2014         PREMIO SECO $10 MILLONES    2461      4
# 7         2   2216  2/01/2014         PREMIO SECO $10 MILLONES    2542     78
# 8         2   2216  2/01/2014         PREMIO SECO $10 MILLONES    2253     52
# 9         2   2216  2/01/2014         PREMIO SECO $10 MILLONES    8690    193
# 10        2   2216  2/01/2014         PREMIO SECO $10 MILLONES    8065    186
# ...

# %%
# leer archivo csv
csv1 = pd.read_csv(
    'D:/Michael/miloto/ArchivosExcel/resultados-loteria-de-bogota-2022.csv', sep=';' , encoding='latin1'
)

# mostrar las primeras filas del dataframe
print(csv1.head(50))
# Out:
#     LOTERIA SORTEO      FECHA                    NOMBRE_PREMIO  NUMERO  SERIE
# 0         2   2216  2/01/2014  PREMIO MAYOR DE $2.800 MILLONES    4316     48
# 1         2   2216  2/01/2014         PREMIO SECO $10 MILLONES    5777     41
# 2         2   2216  2/01/2014         PREMIO SECO $10 MILLONES    1873    110
# 3         2   2216  2/01/2014         PREMIO SECO $10 MILLONES    6850     67
# 4         2   2216  2/01/2014         PREMIO SECO $10 MILLONES    1731     85
# 5         2   2216  2/01/2014         PREMIO SECO $10 MILLONES    9250      1
# 6         2   2216  2/01/2014         PREMIO SECO $10 MILLONES    2461      4
# 7         2   2216  2/01/2014         PREMIO SECO $10 MILLONES    2542     78
# 8         2   2216  2/01/2014         PREMIO SECO $10 MILLONES    2253     52
# 9         2   2216  2/01/2014         PREMIO SECO $10 MILLONES    8690    193
# 10        2   2216  2/01/2014         PREMIO SECO $10 MILLONES    8065    186
# ...
